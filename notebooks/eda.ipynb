# %% [markdown]
# # EDA: датасет признаков
#
# 1. Заполните `data/raw/real/` и `data/raw/ai/` изображениями.
# 2. Выполните `python scripts/build_dataset.py` из корня репозитория.
# 3. Запустите ячейки ниже для распределений и корреляций.

# %%
import sys
from pathlib import Path
import pandas as pd

ROOT = Path.cwd()
if not (ROOT / "ml").is_dir():
    ROOT = ROOT.parent
csv_path = ROOT / "data" / "processed" / "features.csv"
df = pd.read_csv(csv_path)
df.head(), df["label"].value_counts()

# %%
df.describe().T.head(15)
